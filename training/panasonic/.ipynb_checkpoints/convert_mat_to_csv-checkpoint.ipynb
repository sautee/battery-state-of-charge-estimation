# %% [markdown]
# ## Notebook to convert .mat MATLAB files to CSV
# Panasonic 18650PF Li-ion Battery Data - https://data.mendeley.com/datasets/wykht8y7tg/1
#
# Kollmeyer, Phillip (2018), “Panasonic 18650PF Li-ion Battery Data”, Mendeley Data, V1, doi: 10.17632/wykht8y7tg.1

# %%
import os
import scipy.io
import pandas as pd
import numpy as np

data_path = '../datasets/Panasonic_18650PF'

# %%
def poptime(row):
   return row[0][0]

def convert_mat2csv(mat_file):
    mat_columns = ['TimeStamp', 'Voltage', 'Current', 'Ah', 'Wh', 'Power', 'Battery_Temp_degC', 'Time', 'Chamber_Temp_degC']
    mat_load = scipy.io.loadmat(mat_file)
    mat = mat_load['meas']
    # print(mat.dtype)
    data = []
    for column in mat_columns:
        df = pd.DataFrame(mat[column][0,0])
        df.rename(columns={0:column}, inplace=True)
        data.append(df)
    df = pd.concat(data, axis=1) 
    df['TimeStamp'] = df.apply(poptime, axis=1)
    df.set_index('TimeStamp', inplace=True)
    df.to_csv(os.path.splitext(mat_file)[0]+'.csv')

# %%
# recursively get '.mat' files and convert them to csv
# use cmd -> "dir *.mat /s" on the parent folder to get count of files and match with 'count'
count = 0
for folders in os.listdir(data_path):
    level_1_d = os.path.join(data_path, folders)
    sub_folders = os.listdir(level_1_d)           
    for folder in sub_folders:
        level_2_d = os.path.join(level_1_d, folder)
        if os.path.isdir(level_2_d): 
            for file in os.listdir(level_2_d):
                if file.endswith('.mat'):
                    count = count + 1
                    print(os.path.join(level_2_d, file))
                    convert_mat2csv(os.path.join(level_2_d, file))
        elif level_2_d.endswith('.mat'):
            count = count + 1
            print(level_2_d)
            convert_mat2csv(level_2_d)
print(count)
# Out:
# ../datasets/Panasonic_18650PF/-10degC/5 pulse test/06-07-17_12.29 n10degC_5pulse_HPPC_Pan18650PF.mat
# [('TimeStamp', 'O'), ('Voltage', 'O'), ('Current', 'O'), ('Ah', 'O'), ('Wh', 'O'), ('Power', 'O'), ('Battery_Temp_degC', 'O'), ('Time', 'O'), ('Chamber_Temp_degC', 'O')]
# ../datasets/Panasonic_18650PF/-10degC/5 pulse test/06-07-17_14.11 3740_dis5_10p.mat
# [('TimeStamp', 'O'), ('Voltage', 'O'), ('Current', 'O'), ('Ah', 'O'), ('Wh', 'O'), ('Power', 'O'), ('Battery_Temp_degC', 'O'), ('Time', 'O'), ('Chamber_Temp_degC', 'O')]
# ../datasets/Panasonic_18650PF/-10degC/Charges and Pauses/06-07-17_08.40 3740_PreChg.mat
# [('TimeStamp', 'O'), ('Voltage', 'O'), ('Current', 'O'), ('Ah', 'O'), ('Wh', 'O'), ('Power', 'O'), ('Battery_Temp_degC', 'O'), ('Time', 'O'), ('Chamber_Temp_degC', 'O')]
# ../datasets/Panasonic_18650PF/-10degC/Charges and Pauses/06-08-17_10.21 3740_Charge1a.mat
# [('TimeStamp', 'O'), ('Voltage', 'O'), ('Current', 'O'), ('Ah', 'O'), ('Wh', 'O'), ('Power', 'O'), ('Battery_Temp_degC', 'O'), ('Time', 'O'), ('Chamber_Temp_degC', 'O')]
# ../datasets/Panasonic_18650PF/-10degC/Charges and Pauses/06-10-17_05.35 3740_Charge2a.mat
# [('TimeStamp', 'O'), ('Voltage', 'O'), ('Current', 'O'), ('Ah', 'O'), ('Wh', 'O'), ('Power', 'O'), ('Battery_Temp_degC', 'O'), ('Time', 'O'), ('Chamber_Temp_degC', 'O')]
# ../datasets/Panasonic_18650PF/-10degC/Charges and Pauses/06-10-17_09.26 3740_Pause1.mat
# [('TimeStamp', 'O'), ('Voltage', 'O'), ('Current', 'O'), ('Ah', 'O'), ('Wh', 'O'), ('Power', 'O'), ('Battery_Temp_degC', 'O'), ('Time', 'O'), ('Chamber_Temp_degC', 'O')]
# ../datasets/Panasonic_18650PF/-10degC/Charges and Pauses/06-10-17_13.07 3740_Charge1.mat
# [('TimeStamp', 'O'), ('Voltage', 'O'), ('Current', 'O'), ('Ah', 'O'), ('Wh', 'O'), ('Power', 'O'), ('Battery_Temp_degC', 'O'), ('Time', 'O'), ('Chamber_Temp_degC', 'O')]
# ../datasets/Panasonic_18650PF/-10degC/Charges and Pauses/06-10-17_16.36 3740_Pause2.mat
# [('TimeStamp', 'O'), ('Voltage', 'O'), ('Current', 'O'), ('Ah', 'O'), ('Wh', 'O'), ('Power', 'O'), ('Battery_Temp_degC', 'O'), ('Time', 'O'), ('Chamber_Temp_degC', 'O')]
# ../datasets/Panasonic_18650PF/-10degC/Charges and Pauses/06-10-17_20.16 3740_Charge2.mat
# [('TimeStamp', 'O'), ('Voltage', 'O'), ('Current', 'O'), ('Ah', 'O'), ('Wh', 'O'), ('Power', 'O'), ('Battery_Temp_degC', 'O'), ('Time', 'O'), ('Chamber_Temp_degC', 'O')]
# ../datasets/Panasonic_18650PF/-10degC/Charges and Pauses/06-10-17_23.40 3740_Pause3.mat
# [('TimeStamp', 'O'), ('Voltage', 'O'), ('Current', 'O'), ('Ah', 'O'), ('Wh', 'O'), ('Power', 'O'), ('Battery_Temp_degC', 'O'), ('Time', 'O'), ('Chamber_Temp_degC', 'O')]
# ../datasets/Panasonic_18650PF/-10degC/Charges and Pauses/06-11-17_03.15 3740_Charge3.mat
# [('TimeStamp', 'O'), ('Voltage', 'O'), ('Current', 'O'), ('Ah', 'O'), ('Wh', 'O'), ('Power', 'O'), ('Battery_Temp_degC', 'O'), ('Time', 'O'), ('Chamber_Temp_degC', 'O')]
# ../datasets/Panasonic_18650PF/-10degC/Charges and Pauses/06-11-17_06.43 3740_Pause4.mat
# [('TimeStamp', 'O'), ('Voltage', 'O'), ('Current', 'O'), ('Ah', 'O'), ('Wh', 'O'), ('Power', 'O'), ('Battery_Temp_degC', 'O'), ('Time', 'O'), ('Chamber_Temp_degC', 'O')]
# ../datasets/Panasonic_18650PF/-10degC/Charges and Pauses/06-14-17_08.03 3787_TS003396.mat
# [('TimeStamp', 'O'), ('Voltage', 'O'), ('Current', 'O'), ('Ah', 'O'), ('Wh', 'O'), ('Power', 'O'), ('Battery_Temp_degC', 'O'), ('Time', 'O'), ('Chamber_Temp_degC', 'O')]
# ../datasets/Panasonic_18650PF/-10degC/Charges and Pauses/06-14-17_08.04 3787_Charge8.mat
# [('TimeStamp', 'O'), ('Voltage', 'O'), ('Current', 'O'), ('Ah', 'O'), ('Wh', 'O'), ('Power', 'O'), ('Battery_Temp_degC', 'O'), ('Time', 'O'), ('Chamber_Temp_degC', 'O')]
# ../datasets/Panasonic_18650PF/-10degC/Charges and Pauses/06-14-17_11.13 3787_Pause9.mat
# [('TimeStamp', 'O'), ('Voltage', 'O'), ('Current', 'O'), ('Ah', 'O'), ('Wh', 'O'), ('Power', 'O'), ('Battery_Temp_degC', 'O'), ('Time', 'O'), ('Chamber_Temp_degC', 'O')]
# ../datasets/Panasonic_18650PF/-10degC/Charges and Pauses/06-14-17_14.40 3787_Charge9.mat
# [('TimeStamp', 'O'), ('Voltage', 'O'), ('Current', 'O'), ('Ah', 'O'), ('Wh', 'O'), ('Power', 'O'), ('Battery_Temp_degC', 'O'), ('Time', 'O'), ('Chamber_Temp_degC', 'O')]
# ../datasets/Panasonic_18650PF/-10degC/Drive Cycles/06-07-17_08.39 n10degC_HWFET_Pan18650PF.mat
# [('TimeStamp', 'O'), ('Voltage', 'O'), ('Current', 'O'), ('Ah', 'O'), ('Wh', 'O'), ('Power', 'O'), ('Battery_Temp_degC', 'O'), ('Time', 'O'), ('Chamber_Temp_degC', 'O')]
# ../datasets/Panasonic_18650PF/-10degC/Drive Cycles/06-07-17_08.39 n10degC_LA92_Pan18650PF.mat
# [('TimeStamp', 'O'), ('Voltage', 'O'), ('Current', 'O'), ('Ah', 'O'), ('Wh', 'O'), ('Power', 'O'), ('Battery_Temp_degC', 'O'), ('Time', 'O'), ('Chamber_Temp_degC', 'O')]
# ../datasets/Panasonic_18650PF/-10degC/Drive Cycles/06-07-17_08.39 n10degC_UDDS_Pan18650PF.mat
# [('TimeStamp', 'O'), ('Voltage', 'O'), ('Current', 'O'), ('Ah', 'O'), ('Wh', 'O'), ('Power', 'O'), ('Battery_Temp_degC', 'O'), ('Time', 'O'), ('Chamber_Temp_degC', 'O')]
# ../datasets/Panasonic_18650PF/-10degC/Drive Cycles/06-07-17_08.39 n10degC_US06_HWFET_UDDS_LA92_Pan18650PF.mat
# [('TimeStamp', 'O'), ('Voltage', 'O'), ('Current', 'O'), ('Ah', 'O'), ('Wh', 'O'), ('Power', 'O'), ('Battery_Temp_degC', 'O'), ('Time', 'O'), ('Chamber_Temp_degC', 'O')]
# ../datasets/Panasonic_18650PF/-10degC/Drive Cycles/06-07-17_08.39 n10degC_US06_Pan18650PF.mat
# [('TimeStamp', 'O'), ('Voltage', 'O'), ('Current', 'O'), ('Ah', 'O'), ('Wh', 'O'), ('Power', 'O'), ('Battery_Temp_degC', 'O'), ('Time', 'O'), ('Chamber_Temp_degC', 'O')]
# ../datasets/Panasonic_18650PF/-10degC/Drive Cycles/06-10-17_11.25 n10degC_Cycle_1_Pan18650PF.mat
# [('TimeStamp', 'O'), ('Voltage', 'O'), ('Current', 'O'), ('Ah', 'O'), ('Wh', 'O'), ('Power', 'O'), ('Battery_Temp_degC', 'O'), ('Time', 'O'), ('Chamber_Temp_degC', 'O')]
# ../datasets/Panasonic_18650PF/-10degC/Drive Cycles/06-10-17_18.35 n10degC_Cycle_2_Pan18650PF.mat
# [('TimeStamp', 'O'), ('Voltage', 'O'), ('Current', 'O'), ('Ah', 'O'), ('Wh', 'O'), ('Power', 'O'), ('Battery_Temp_degC', 'O'), ('Time', 'O'), ('Chamber_Temp_degC', 'O')]
# ../datasets/Panasonic_18650PF/-10degC/Drive Cycles/06-11-17_01.39 n10degC_Cycle_3_Pan18650PF.mat
# [('TimeStamp', 'O'), ('Voltage', 'O'), ('Current', 'O'), ('Ah', 'O'), ('Wh', 'O'), ('Power', 'O'), ('Battery_Temp_degC', 'O'), ('Time', 'O'), ('Chamber_Temp_degC', 'O')]
# ../datasets/Panasonic_18650PF/-10degC/Drive Cycles/06-11-17_08.42 n10degC_Cycle_4_Pan18650PF.mat
# [('TimeStamp', 'O'), ('Voltage', 'O'), ('Current', 'O'), ('Ah', 'O'), ('Wh', 'O'), ('Power', 'O'), ('Battery_Temp_degC', 'O'), ('Time', 'O'), ('Chamber_Temp_degC', 'O')]
# ../datasets/Panasonic_18650PF/-10degC/Drive Cycles/06-14-17_13.12 n10degC_NN_Pan18650PF.mat
# [('TimeStamp', 'O'), ('Voltage', 'O'), ('Current', 'O'), ('Ah', 'O'), ('Wh', 'O'), ('Power', 'O'), ('Battery_Temp_degC', 'O'), ('Time', 'O'), ('Chamber_Temp_degC', 'O')]
# ../datasets/Panasonic_18650PF/-20degC/5 pulse disch/06-15-17_11.31 n20degC_5Pulse_HPPC_Pan18650PF.mat
# [('TimeStamp', 'O'), ('Voltage', 'O'), ('Current', 'O'), ('Ah', 'O'), ('Wh', 'O'), ('Power', 'O'), ('Battery_Temp_degC', 'O'), ('Time', 'O'), ('Chamber_Temp_degC', 'O')]
# ../datasets/Panasonic_18650PF/-20degC/5 pulse disch/06-15-17_12.33 3789_dis5_10p.mat
# [('TimeStamp', 'O'), ('Voltage', 'O'), ('Current', 'O'), ('Ah', 'O'), ('Wh', 'O'), ('Power', 'O'), ('Battery_Temp_degC', 'O'), ('Time', 'O'), ('Chamber_Temp_degC', 'O')]
# ../datasets/Panasonic_18650PF/-20degC/Charges and Pauses/06-23-17_23.36 3913_Charge2a.mat
# [('TimeStamp', 'O'), ('Voltage', 'O'), ('Current', 'O'), ('Ah', 'O'), ('Wh', 'O'), ('Power', 'O'), ('Battery_Temp_degC', 'O'), ('Time', 'O'), ('Chamber_Temp_degC', 'O')]
# ../datasets/Panasonic_18650PF/-20degC/Charges and Pauses/06-24-17_02.29 3913_Pause1.mat
# [('TimeStamp', 'O'), ('Voltage', 'O'), ('Current', 'O'), ('Ah', 'O'), ('Wh', 'O'), ('Power', 'O'), ('Battery_Temp_degC', 'O'), ('Time', 'O'), ('Chamber_Temp_degC', 'O')]
# ../datasets/Panasonic_18650PF/-20degC/Charges and Pauses/06-24-17_05.54 3913_Charge1.mat
# [('TimeStamp', 'O'), ('Voltage', 'O'), ('Current', 'O'), ('Ah', 'O'), ('Wh', 'O'), ('Power', 'O'), ('Battery_Temp_degC', 'O'), ('Time', 'O'), ('Chamber_Temp_degC', 'O')]
# ../datasets/Panasonic_18650PF/-20degC/Charges and Pauses/06-24-17_09.59 3913_Pause2.mat
# [('TimeStamp', 'O'), ('Voltage', 'O'), ('Current', 'O'), ('Ah', 'O'), ('Wh', 'O'), ('Power', 'O'), ('Battery_Temp_degC', 'O'), ('Time', 'O'), ('Chamber_Temp_degC', 'O')]
# ../datasets/Panasonic_18650PF/-20degC/Charges and Pauses/06-24-17_13.23 3913_Charge2.mat
# [('TimeStamp', 'O'), ('Voltage', 'O'), ('Current', 'O'), ('Ah', 'O'), ('Wh', 'O'), ('Power', 'O'), ('Battery_Temp_degC', 'O'), ('Time', 'O'), ('Chamber_Temp_degC', 'O')]
# ../datasets/Panasonic_18650PF/-20degC/Charges and Pauses/06-24-17_17.30 3913_Pause3.mat
# [('TimeStamp', 'O'), ('Voltage', 'O'), ('Current', 'O'), ('Ah', 'O'), ('Wh', 'O'), ('Power', 'O'), ('Battery_Temp_degC', 'O'), ('Time', 'O'), ('Chamber_Temp_degC', 'O')]
# ../datasets/Panasonic_18650PF/-20degC/Charges and Pauses/06-24-17_20.54 3913_Charge3.mat
# [('TimeStamp', 'O'), ('Voltage', 'O'), ('Current', 'O'), ('Ah', 'O'), ('Wh', 'O'), ('Power', 'O'), ('Battery_Temp_degC', 'O'), ('Time', 'O'), ('Chamber_Temp_degC', 'O')]
# ../datasets/Panasonic_18650PF/-20degC/Charges and Pauses/06-25-17_01.02 3913_Pause4.mat
# [('TimeStamp', 'O'), ('Voltage', 'O'), ('Current', 'O'), ('Ah', 'O'), ('Wh', 'O'), ('Power', 'O'), ('Battery_Temp_degC', 'O'), ('Time', 'O'), ('Chamber_Temp_degC', 'O')]
# ../datasets/Panasonic_18650PF/-20degC/Charges and Pauses/06-25-17_04.26 3913_Charge4.mat
# [('TimeStamp', 'O'), ('Voltage', 'O'), ('Current', 'O'), ('Ah', 'O'), ('Wh', 'O'), ('Power', 'O'), ('Battery_Temp_degC', 'O'), ('Time', 'O'), ('Chamber_Temp_degC', 'O')]
# ../datasets/Panasonic_18650PF/-20degC/Charges and Pauses/06-25-17_08.32 3913_Pause5.mat
# [('TimeStamp', 'O'), ('Voltage', 'O'), ('Current', 'O'), ('Ah', 'O'), ('Wh', 'O'), ('Power', 'O'), ('Battery_Temp_degC', 'O'), ('Time', 'O'), ('Chamber_Temp_degC', 'O')]
# ../datasets/Panasonic_18650PF/-20degC/Charges and Pauses/06-25-17_11.16 3913_Charge5.mat
# [('TimeStamp', 'O'), ('Voltage', 'O'), ('Current', 'O'), ('Ah', 'O'), ('Wh', 'O'), ('Power', 'O'), ('Battery_Temp_degC', 'O'), ('Time', 'O'), ('Chamber_Temp_degC', 'O')]
# ../datasets/Panasonic_18650PF/-20degC/Drive cycles/06-23-17_23.35 n20degC_HWFET_Pan18650PF.mat
# [('TimeStamp', 'O'), ('Voltage', 'O'), ('Current', 'O'), ('Ah', 'O'), ('Wh', 'O'), ('Power', 'O'), ('Battery_Temp_degC', 'O'), ('Time', 'O'), ('Chamber_Temp_degC', 'O')]
# ../datasets/Panasonic_18650PF/-20degC/Drive cycles/06